# %%
import matplotlib.pyplot as plt
import pickle as pkl
import numpy as np
import sys

# %%
losses_idx = 0
accuracy_idx = 1

train_idx = 0
val_idx = 1
test_idx = 2

# %%
metrics = None
with open('metrics.pkl', 'rb') as f:
    metrics = pkl.load(f)

# %%
plt.plot(range(len(metrics)), [train[accuracy_idx] for train, val, test in metrics], label="train accuracy", )
plt.plot(range(len(metrics)), [val[accuracy_idx] for train, val, test in metrics], label="validation accuracy")
plt.plot(range(len(metrics)), [test[accuracy_idx] for train, val, test in metrics], label="test accuracy")
plt.legend()
plt.plot()
# Out:
# []
